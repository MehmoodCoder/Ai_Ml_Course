# %% [markdown]
# <a href="https://colab.research.google.com/github/MehmoodCoder/Ai_Ml_Course/blob/main/Ai_Ml_Main_numpy_intro_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Image Reading***

# %%
from matplotlib.image import imread

img_data = imread("/bmw.jpeg")

img_data
# Out:
# array([[[ 92, 114, 128],
#         [ 94, 116, 130],
#         [ 95, 117, 131],
#         ...,
#         [ 56,  77,  98],
#         [ 56,  77,  98],
#         [ 56,  77,  98]],
#
#        [[ 88, 110, 124],
#         [ 92, 114, 128],
#         [ 98, 120, 134],
#         ...,
#         [ 56,  77,  98],
#         [ 56,  77,  98],
#         [ 56,  77,  98]],
#
#        [[ 81, 100, 115],
#         [ 84, 103, 118],
#         [ 86, 105, 120],
#         ...,
#         [ 57,  78,  99],
#         [ 57,  78,  99],
#         [ 57,  78,  99]],
#
#        ...,
#
#        [[ 19,  31,  47],
#         [ 19,  31,  47],
#         [ 19,  31,  47],
#         ...,
#         [ 24,  36,  52],
#         [ 24,  36,  52],
#         [ 24,  36,  52]],
#
#        [[ 19,  31,  47],
#         [ 19,  31,  47],
#         [ 19,  31,  47],
#         ...,
#         [ 24,  36,  52],
#         [ 24,  36,  52],
#         [ 24,  36,  52]],
#
#        [[ 19,  31,  47],
#         [ 19,  31,  47],
#         [ 19,  31,  47],
# ...

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(img_data)
plt.show()

# %%
img_data.shape
# Out:
# (168, 299, 3)
